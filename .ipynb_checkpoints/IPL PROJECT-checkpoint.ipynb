# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sea

# %%
#load a ipl dataset
ipl = pd.read_csv(r'matches.csv')
ipl
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
#TO SEE FIRST 5 ROWS OF DATA
ipl.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#TO KNOW THE NUMBER OF ROWS AND COLUMNS
ipl.shape
# Out:
# (756, 18)

# %%
#TO KNOW THE FREQUENCY OF MAN OF THE MATCHES
ipl['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: player_of_match, Length: 226, dtype: int64

# %%
#TO KNOW 10 HIGHEST NUMBER OF MAN OF THE MATCHES WINNERS
ipl['player_of_match'].value_counts()[0:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
#TO KNOW TOP 5 MAN OF THE MATCH WINNERS
ipl['player_of_match'].value_counts()[0:5]
# Out:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# Name: player_of_match, dtype: int64

# %%
ll=list(ipl['player_of_match'].value_counts()[0:5].keys())

# %%
#GETTING A BAR-PLOT OF MOST PLAYER OF THE MATCH WINNERS
plt.figure(figsize=(10,5))
plt.bar(list(ipl['player_of_match'].value_counts()[0:5].keys()),ipl['player_of_match'].value_counts()[0:5])
plt.title("MOST MAN OF THE MATCH WINNERS")
plt.xlabel('PLAYERS')
plt.ylabel('Numbers')
# Out:
# Text(0, 0.5, 'Numbers')

# %%
#GETTING FREQUENCY OF RESULT 
ipl['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
#FINDING TOSS WINS W.R.T TEAMS
ipl['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
#GETTING DATA OF TEAMS WHO WON BY BATTING FIRST
bat_first = ipl[ipl['win_by_runs']!=0]
bat_first
# Out:
#         id    Season       city        date                        team1  \
# 0        1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4        5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8        9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13      14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14      15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
# ..     ...       ...        ...         ...                          ...
# 741  11337  IPL-2019      Delhi  28-04-2019               Delhi Capitals
# 742  11338  IPL-2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 743  11339  IPL-2019  Hyderabad  29-04-2019          Sunrisers Hyderabad
# 745  11341  IPL-2019    Chennai  01-05-2019          Chennai Super Kings
# 755  11415  IPL-2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
bat_first.head()
# Out:
#     id    Season       city        date                        team1  \
# 0    1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 4    5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017       Pune  11-04-2017             Delhi Daredevils
# 13  14  IPL-2017    Kolkata  15-04-2017        Kolkata Knight Riders
# 14  15  IPL-2017      Delhi  15-04-2017             Delhi Daredevils
#
#                           team2                  toss_winner toss_decision  \
# 0   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 4              Delhi Daredevils  Royal Challengers Bangalore           bat
# 8        Rising Pune Supergiant       Rising Pune Supergiant         field
# 13          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
#
#     result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#MAKING A HISTOGRAM FOR RUNS WIN BY THE TEAMS
plt.figure(figsize=(10,5))
plt.hist(bat_first['win_by_runs'],bins=7)
# Out:
# (array([164., 101.,  33.,  19.,  12.,   3.,   5.]),
#  array([  1.        ,  21.71428571,  42.42857143,  63.14285714,
#          83.85714286, 104.57142857, 125.28571429, 146.        ]),
#  <BarContainer object of 7 artists>)

# %%
#FREQUENCY OF TEAMS WIN BY BATTING FIRST
bat_first['winner'].value_counts()
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Rising Pune Supergiant          5
# Delhi Capitals                  3
# Kochi Tuskers Kerala            2
# Rising Pune Supergiants         2
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
#TOP 3 TEAMS MOST WINS BY BATTING FIRST
bat_first['winner'].value_counts()[0:3]
# Out:
# Mumbai Indians         57
# Chennai Super Kings    52
# Kings XI Punjab        38
# Name: winner, dtype: int64

# %%
#MAKING A BAR-PLOT OF TOP 3 TEAMS WIN BY BATTING FIRST
plt.figure(figsize=(10,5))
plt.bar(list(bat_first['winner'].value_counts()[0:3].keys()),bat_first['winner'].value_counts()[0:3],color=['blue','yellow','red'])
plt.title('WIN BY BATTING FIRST')
plt.xlabel('TEAMS')
plt.ylabel('NUMBERS')
# Out:
# Text(0, 0.5, 'NUMBERS')

# %%
#SHOWING BATTING FIRST PERCENT USING PIE-CHART
plt.figure(figsize = (10,10))
plt.pie(bat_first['winner'].value_counts(),labels = list(bat_first['winner'].value_counts().keys()),autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2249c796fa0>,
# ...
#  [Text(0.9483265621806172, 0.5573838277728304, 'Mumbai Indians'),
#   Text(0.02563386044208945, 1.0997012799841763, 'Chennai Super Kings'),
#   Text(-0.8010226010255528, 0.7538983967659425, 'Kings XI Punjab'),
#   Text(-1.0976587644223588, 0.07173030661290015, 'Kolkata Knight Riders'),
#   Text(-0.9099615286095598, -0.6180372290166294, 'Royal Challengers Bangalore'),
#   Text(-0.3959592959126898, -1.0262632391254825, 'Sunrisers Hyderabad'),
#   Text(0.1786580387418249, -1.08539453895481, 'Rajasthan Royals'),
#   Text(0.6638604303770628, -0.8770914028649359, 'Delhi Daredevils'),
#   Text(0.9534813337914305, -0.5485192303933517, 'Deccan Chargers'),
#   Text(1.0514175368316108, -0.32329732947079654, 'Pune Warriors'),
#   Text(1.0789886618399935, -0.21397071673651988, 'Rising Pune Supergiant'),
#   Text(1.0919321532371848, -0.1329818511181329, 'Delhi Capitals'),
#   Text(1.0969423967462106, -0.08195961335120551, 'Kochi Tuskers Kerala'),
# ...

# %%
#TEAMS WON BY BATTING SECOND
bat_second = ipl[ipl['win_by_wickets']!=0]
bat_second
# Out:
#         id    Season           city        date                   team1  \
# 1        2  IPL-2017           Pune  06-04-2017          Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017           Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017  Rising Pune Supergiant
# 5        6  IPL-2017      Hyderabad  09-04-2017           Gujarat Lions
# 6        7  IPL-2017         Mumbai  09-04-2017   Kolkata Knight Riders
# ..     ...       ...            ...         ...                     ...
# 750  11346  IPL-2019         Mohali  05-05-2019     Chennai Super Kings
# 751  11347  IPL-2019         Mumbai  05-05-2019   Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019     Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019     Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
bat_second.head()
# Out:
#    id    Season       city        date                   team1  \
# 1   2  IPL-2017       Pune  06-04-2017          Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017           Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017  Rising Pune Supergiant
# 5   6  IPL-2017  Hyderabad  09-04-2017           Gujarat Lions
# 6   7  IPL-2017     Mumbai  09-04-2017   Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders   Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab         Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# ...

# %%
#MAKING A HISTOGRAM FOR THE TEAMS WIN BY SECOND BATTING W.R.T WICKETS
plt.figure(figsize = (10,5))
plt.hist(bat_second['win_by_wickets'],color = 'y',bins = 10)
plt.title('Teams win by wickets')
plt.xlabel('WICKETS')
plt.grid(True)

# %%
#TEAMS WHO HAVE WON MOST NUMBER OF MATCHES BATTING SECOND
bat_second['winner'].value_counts()
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Kings XI Punjab                42
# Delhi Daredevils               42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Delhi Capitals                  6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
bat_second['winner'].value_counts()[0:5]
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Royal Challengers Bangalore    48
# Chennai Super Kings            48
# Rajasthan Royals               46
# Name: winner, dtype: int64

# %%
#MAKING A PIE-CHART OF TEAMS WINNING BATTING SECOND
plt.figure(figsize = (10,10))
plt.pie(bat_second['winner'].value_counts(),labels = list(bat_second['winner'].value_counts().keys()),autopct = '%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2249c8cfc10>,
# ...
#  [Text(0.9983329623836416, 0.4618780101047276, 'Kolkata Knight Riders'),
#   Text(0.34315510477407346, 1.0451050540818827, 'Mumbai Indians'),
#   Text(-0.469589129872304, 0.994729133536247, 'Royal Challengers Bangalore'),
#   Text(-1.0186933326018242, 0.415046857731256, 'Chennai Super Kings'),
#   Text(-1.0368582653410094, -0.3673213002182603, 'Rajasthan Royals'),
#   Text(-0.5743854605141011, -0.9381265067942618, 'Kings XI Punjab'),
#   Text(0.1104657133114124, -1.094439274780744, 'Delhi Daredevils'),
#   Text(0.6520603064504145, -0.8858991797895467, 'Sunrisers Hyderabad'),
#   Text(0.8858992637336905, -0.6520601924025918, 'Gujarat Lions'),
#   Text(0.987343061874614, -0.48492646676384094, 'Deccan Chargers'),
#   Text(1.0424185113345334, -0.3512316147887253, 'Pune Warriors'),
#   Text(1.0704946012627996, -0.2530638430657369, 'Delhi Capitals'),
#   Text(1.0881331687620566, -0.16114033337388253, 'Rising Pune Supergiant'),
# ...

# %%
plt.figure(figsize = (12,9))
plt.pie(ipl['winner'].value_counts(),labels = list(ipl['winner'].value_counts().keys()),autopct = '%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2249cb07520>,
# ...
#  [Text(0.9879111799530969, 0.4837680234613281, 'Mumbai Indians'),
#   Text(0.26393358858840527, 1.0678665931729705, 'Chennai Super Kings'),
#   Text(-0.584123164342328, 0.932094484952414, 'Kolkata Knight Riders'),
#   Text(-1.058450924134978, 0.29946893194087976, 'Royal Challengers Bangalore'),
#   Text(-1.005397793117458, -0.4462905752920907, 'Kings XI Punjab'),
#   Text(-0.524605323356602, -0.9668450003521325, 'Rajasthan Royals'),
#   Text(0.10553204184873356, -1.0949260194840733, 'Delhi Daredevils'),
#   Text(0.6376088225019216, -0.8963565080188314, 'Sunrisers Hyderabad'),
#   Text(0.9146165949894981, -0.6111272242093432, 'Deccan Chargers'),
#   Text(1.007253493369899, -0.44208641699800627, 'Gujarat Lions'),
#   Text(1.0478530986488637, -0.3346698128782679, 'Pune Warriors'),
#   Text(1.0741461813830273, -0.23708644208444513, 'Rising Pune Supergiant'),
#   Text(1.0901852418806335, -0.14661561439923335, 'Delhi Capitals'),
# ...

# %%
#A BAR-PLOT OF TOP 3 TEAMS WINNING BATTING SECOND
plt.figure(figsize = (10,6))
plt.bar(list(bat_second['winner'].value_counts()[0:3].keys()),bat_second['winner'].value_counts()[0:3],color=['purple','blue','red'])
# Out:
# <BarContainer object of 3 artists>

# %%
#NUMBER OF MATCHES PLAYED IN EACH SEASON
ipl['Season'].value_counts()
# Out:
# IPL-2013    76
# IPL-2012    74
# IPL-2011    73
# IPL-2010    60
# IPL-2014    60
# IPL-2016    60
# IPL-2018    60
# IPL-2019    60
# IPL-2017    59
# IPL-2015    59
# IPL-2008    58
# IPL-2009    57
# Name: Season, dtype: int64

# %%
#MATCHES PLAYED IN EACH CITY
ipl['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
#FINDING OUT HOW MANY TIMES A TEAM WON AFTER WINNING THE TOSS
np.sum(ipl['toss_winner'] == ipl['winner'])
# Out:
# 393

# %%
#CHANCE OF TOSS WIN MATCH WIN
ipl.shape
# Out:
# (756, 18)

# %%
393/756
# Out:
# 0.5198412698412699

# %%
#LOADING DELIVERIES DATASET
deliveries = pd.read_csv(r'deliveries.csv')
deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
match1 = deliveries[deliveries['match_id']==1]
match1
# Out:
#      match_id  inning                 batting_team  \
# 0           1       1          Sunrisers Hyderabad
# 1           1       1          Sunrisers Hyderabad
# 2           1       1          Sunrisers Hyderabad
# 3           1       1          Sunrisers Hyderabad
# 4           1       1          Sunrisers Hyderabad
# ..        ...     ...                          ...
# 243         1       2  Royal Challengers Bangalore
# 244         1       2  Royal Challengers Bangalore
# 245         1       2  Royal Challengers Bangalore
# 246         1       2  Royal Challengers Bangalore
# 247         1       2  Royal Challengers Bangalore
#
#                     bowling_team  over  ball      batsman  non_striker  \
# 0    Royal Challengers Bangalore     1     1    DA Warner     S Dhawan
# 1    Royal Challengers Bangalore     1     2    DA Warner     S Dhawan
# 2    Royal Challengers Bangalore     1     3    DA Warner     S Dhawan
# ...

# %%
srh = match1[match1['inning']==1]

# %%
srh.shape
# Out:
# (125, 21)

# %%
#RUN DISTRIBUTIN OF SRH
srh['batsman_runs'].value_counts()
# Out:
# 1    57
# 0    32
# 4    17
# 6     9
# 2     9
# 3     1
# Name: batsman_runs, dtype: int64

# %%
match1['dismissal_kind'].value_counts()
# Out:
# caught     9
# bowled     3
# run out    2
# Name: dismissal_kind, dtype: int64

# %%
srh['dismissal_kind'].value_counts()
# Out:
# caught    3
# bowled    1
# Name: dismissal_kind, dtype: int64

# %%
rcb = match1[match1['inning']==2]
rcb
# Out:
#      match_id  inning                 batting_team         bowling_team  over  \
# 125         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 126         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 127         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 128         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# 129         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad     1
# ..        ...     ...                          ...                  ...   ...
# 243         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    19
# 244         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
# 245         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
# 246         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
# 247         1       2  Royal Challengers Bangalore  Sunrisers Hyderabad    20
#
# ...

# %%
rcb.shape
# Out:
# (123, 21)

# %%
rcb['batsman_runs'].value_counts()
# Out:
# 0    49
# 1    44
# 4    15
# 6     8
# 2     7
# Name: batsman_runs, dtype: int64

# %%
rcb['dismissal_kind'].value_counts()
# Out:
# caught     6
# bowled     2
# run out    2
# Name: dismissal_kind, dtype: int64

# %%
#ANOTHER MATCH ANALYSIS
match50 = deliveries[deliveries['match_id']==50]
match50
# Out:
#        match_id  inning     batting_team     bowling_team  over  ball  \
# 11596        50       1  Kings XI Punjab   Mumbai Indians     1     1
# 11597        50       1  Kings XI Punjab   Mumbai Indians     1     2
# 11598        50       1  Kings XI Punjab   Mumbai Indians     1     3
# 11599        50       1  Kings XI Punjab   Mumbai Indians     1     4
# 11600        50       1  Kings XI Punjab   Mumbai Indians     1     5
# ...         ...     ...              ...              ...   ...   ...
# 11846        50       2   Mumbai Indians  Kings XI Punjab    20     2
# 11847        50       2   Mumbai Indians  Kings XI Punjab    20     3
# 11848        50       2   Mumbai Indians  Kings XI Punjab    20     4
# 11849        50       2   Mumbai Indians  Kings XI Punjab    20     5
# 11850        50       2   Mumbai Indians  Kings XI Punjab    20     6
#
#           batsman      non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
match50.shape
# Out:
# (255, 21)

# %%
kp = match50[match50['inning']==1]

# %%
kp
# Out:
#        match_id  inning     batting_team    bowling_team  over  ball  \
# 11596        50       1  Kings XI Punjab  Mumbai Indians     1     1
# 11597        50       1  Kings XI Punjab  Mumbai Indians     1     2
# 11598        50       1  Kings XI Punjab  Mumbai Indians     1     3
# 11599        50       1  Kings XI Punjab  Mumbai Indians     1     4
# 11600        50       1  Kings XI Punjab  Mumbai Indians     1     5
# ...         ...     ...              ...             ...   ...   ...
# 11720        50       1  Kings XI Punjab  Mumbai Indians    20     3
# 11721        50       1  Kings XI Punjab  Mumbai Indians    20     4
# 11722        50       1  Kings XI Punjab  Mumbai Indians    20     5
# 11723        50       1  Kings XI Punjab  Mumbai Indians    20     6
# 11724        50       1  Kings XI Punjab  Mumbai Indians    20     7
#
#           batsman non_striker     bowler  is_super_over  ...  bye_runs  \
# ...

# %%
kp.shape
# Out:
# (129, 21)

# %%
kp['total_runs'].value_counts()
# Out:
# 1    63
# 0    26
# 4    17
# 2    10
# 6    10
# 7     2
# 5     1
# Name: total_runs, dtype: int64

# %%
kp['extra_runs'].value_counts()
# Out:
# 0    119
# 1     10
# Name: extra_runs, dtype: int64

# %%
np.sum(kp['total_runs'].value_counts())
# Out:
# 129

# %%
kp['batsman'].value_counts()
# Out:
# WP Saha       59
# GJ Maxwell    22
# MJ Guptill    18
# SE Marsh      17
# AR Patel      13
# Name: batsman, dtype: int64

# %%
kp['bowler'].value_counts()
# Out:
# MJ McClenaghan     28
# SL Malinga         28
# JJ Bumrah          24
# KV Sharma          18
# Harbhajan Singh    18
# HH Pandya          13
# Name: bowler, dtype: int64

# %%
mi = match50[match50['inning']==2]
mi
# Out:
#        match_id  inning    batting_team     bowling_team  over  ball  \
# 11725        50       2  Mumbai Indians  Kings XI Punjab     1     1
# 11726        50       2  Mumbai Indians  Kings XI Punjab     1     2
# 11727        50       2  Mumbai Indians  Kings XI Punjab     1     3
# 11728        50       2  Mumbai Indians  Kings XI Punjab     1     4
# 11729        50       2  Mumbai Indians  Kings XI Punjab     1     5
# ...         ...     ...             ...              ...   ...   ...
# 11846        50       2  Mumbai Indians  Kings XI Punjab    20     2
# 11847        50       2  Mumbai Indians  Kings XI Punjab    20     3
# 11848        50       2  Mumbai Indians  Kings XI Punjab    20     4
# 11849        50       2  Mumbai Indians  Kings XI Punjab    20     5
# 11850        50       2  Mumbai Indians  Kings XI Punjab    20     6
#
#            batsman      non_striker          bowler  is_super_over  ...  \
# ...

# %%
mi['total_runs'].value_counts()
# Out:
# 1    46
# 0    38
# 4    18
# 6    14
# 2     9
# 3     1
# Name: total_runs, dtype: int64

# %%
np.sum(mi['total_runs'].value_counts())
# Out:
# 126

# %%
mi['batsman'].value_counts()
# Out:
# LMP Simmons        33
# KA Pollard         26
# PA Patel           24
# HH Pandya          14
# N Rana             12
# RG Sharma           7
# KV Sharma           6
# Harbhajan Singh     4
# Name: batsman, dtype: int64

# %%
#PLOTTING BAR-PLOT FOR MI BATSMAN
plt.figure(figsize = (12,4))
plt.bar(list(mi['batsman'].value_counts().keys()),mi['batsman'].value_counts(),color = 'b')
plt.title('MI BATSMAN')
# Out:
# Text(0.5, 1.0, 'MI BATSMAN')
